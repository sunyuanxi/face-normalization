# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
boxes_010 = np.load('010.npy')
boxes_041 = np.load('041.npy')
boxes_050 = np.load('050.npy')
boxes_080 = np.load('080.npy')
boxes_090 = np.load('090.npy')
boxes_110 = np.load('110.npy')
boxes_120 = np.load('120.npy')
boxes_130 = np.load('130.npy')
boxes_140 = np.load('140.npy')
boxes_190 = np.load('190.npy')
boxes_200 = np.load('200.npy')
boxes_240 = np.load('240.npy')

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_010[:, 0], bins=200)
plt.title(str(stats.mode(boxes_010[:, 0]).mode[0]))
plt.subplot(222)
plt.hist(boxes_010[:, 1], bins=200)
plt.title(str(stats.mode(boxes_010[:, 1]).mode[0]))
plt.subplot(223)
plt.hist(boxes_010[:, 2], bins=200)
plt.title(str(stats.mode(boxes_010[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_010[:, 3], bins=200)
plt.title(str(stats.mode(boxes_010[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_010[:, 0], boxes_010[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_041[:, 0], bins=200)
plt.title(str(int(boxes_041[:, 0].mean())))
plt.subplot(222)
plt.hist(boxes_041[:, 1], bins=200)
plt.title(str(int(boxes_041[:, 1].mean())))
plt.subplot(223)
plt.hist(boxes_041[:, 2], bins=200)
plt.title(str(stats.mode(boxes_041[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_041[:, 3], bins=200)
plt.title(str(stats.mode(boxes_041[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_041[:, 0], boxes_041[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_050[:, 0], bins=200)
plt.title(str(stats.mode(boxes_050[:, 0]).mode[0]))
plt.subplot(222)
plt.hist(boxes_050[:, 1], bins=200)
plt.title(str(stats.mode(boxes_050[:, 1]).mode[0]))
plt.subplot(223)
plt.hist(boxes_050[:, 2], bins=200)
plt.title(str(stats.mode(boxes_050[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_050[:, 3], bins=200)
plt.title(str(stats.mode(boxes_050[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_050[:, 0], boxes_050[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_080[:, 0], bins=200)
plt.title(str(int(boxes_080[:, 0].mean())))
plt.subplot(222)
plt.hist(boxes_080[:, 1], bins=200)
plt.title(str(int(boxes_080[:, 1].mean())))
plt.subplot(223)
plt.hist(boxes_080[:, 2], bins=200)
plt.title(str(stats.mode(boxes_080[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_080[:, 3], bins=200)
plt.title(str(stats.mode(boxes_080[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_080[:, 0], boxes_080[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_090[:, 0], bins=200)
plt.title(str(int(boxes_090[:, 0].mean())))
plt.subplot(222)
plt.hist(boxes_090[:, 1], bins=200)
plt.title(str(int(boxes_090[:, 1].mean())))
plt.subplot(223)
plt.hist(boxes_090[:, 2], bins=200)
plt.title(str(stats.mode(boxes_090[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_090[:, 3], bins=200)
plt.title(str(stats.mode(boxes_090[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_090[:, 0], boxes_090[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_110[:, 0], bins=200)
plt.title(str(stats.mode(boxes_110[:, 0]).mode[0]))
plt.subplot(222)
plt.hist(boxes_110[:, 1], bins=200)
plt.title(str(stats.mode(boxes_110[:, 1]).mode[0]))
plt.subplot(223)
plt.hist(boxes_110[:, 2], bins=200)
plt.title(str(stats.mode(boxes_110[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_110[:, 3], bins=200)
plt.title(str(stats.mode(boxes_110[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_110[:, 0], boxes_110[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_120[:, 0], bins=200)
plt.title(str(stats.mode(boxes_120[:, 0]).mode[0]))
plt.subplot(222)
plt.hist(boxes_120[:, 1], bins=200)
plt.title(str(stats.mode(boxes_120[:, 1]).mode[0]))
plt.subplot(223)
plt.hist(boxes_120[:, 2], bins=200)
plt.title(str(stats.mode(boxes_120[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_120[:, 3], bins=200)
plt.title(str(stats.mode(boxes_120[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_120[:, 0], boxes_120[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_130[:, 0], bins=200)
plt.title(str(int(boxes_130[:, 0].mean())))
plt.subplot(222)
plt.hist(boxes_130[:, 1], bins=200)
plt.title(str(int(boxes_130[:, 1].mean())))
plt.subplot(223)
plt.hist(boxes_130[:, 2], bins=200)
plt.title(str(stats.mode(boxes_130[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_130[:, 3], bins=200)
plt.title(str(stats.mode(boxes_130[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_130[:, 0], boxes_130[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_140[:, 0], bins=200)
plt.title(str(int(boxes_140[:, 0].mean())))
plt.subplot(222)
plt.hist(boxes_140[:, 1], bins=200)
plt.title(str(int(boxes_140[:, 1].mean())))
plt.subplot(223)
plt.hist(boxes_140[:, 2], bins=200)
plt.title(str(int(boxes_140[:, 2].mean())))
plt.subplot(224)
plt.hist(boxes_140[:, 3], bins=200)
plt.title(str(int(boxes_140[:, 3].mean())))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_140[:, 0], boxes_140[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_190[:, 0], bins=200)
plt.title(str(int(boxes_190[:, 0].mean())))
plt.subplot(222)
plt.hist(boxes_190[:, 1], bins=200)
plt.title(str(int(boxes_190[:, 1].mean())))
plt.subplot(223)
plt.hist(boxes_190[:, 2], bins=200)
plt.title(str(stats.mode(boxes_190[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_190[:, 3], bins=200)
plt.title(str(stats.mode(boxes_190[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_190[:, 0], boxes_190[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_200[:, 0], bins=200)
plt.title(str(int(boxes_200[:, 0].mean())))
plt.subplot(222)
plt.hist(boxes_200[:, 1], bins=200)
plt.title(str(int(boxes_200[:, 1].mean())))
plt.subplot(223)
plt.hist(boxes_200[:, 2], bins=200)
plt.title(str(stats.mode(boxes_200[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_200[:, 3], bins=200)
plt.title(str(stats.mode(boxes_200[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_200[:, 0], boxes_200[:, 2])
plt.show()

# %%
plt.figure(figsize=(15, 9))
plt.subplot(221)
plt.hist(boxes_240[:, 0], bins=200)
plt.title(str(stats.mode(boxes_240[:, 0]).mode[0]))
plt.subplot(222)
plt.hist(boxes_240[:, 1], bins=200)
plt.title(str(stats.mode(boxes_240[:, 1]).mode[0]))
plt.subplot(223)
plt.hist(boxes_240[:, 2], bins=200)
plt.title(str(stats.mode(boxes_240[:, 2]).mode[0]))
plt.subplot(224)
plt.hist(boxes_240[:, 3], bins=200)
plt.title(str(stats.mode(boxes_240[:, 3]).mode[0]))
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(boxes_240[:, 0], boxes_240[:, 2])
plt.show()
